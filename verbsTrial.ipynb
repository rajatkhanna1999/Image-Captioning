# %%
import nltk.tokenize as nt
import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
text="Jatin nandal who  is backchode in nature is running and doing backchode."
ss=nt.sent_tokenize(text)
tokenized_sent=[nt.word_tokenize(sent) for sent in ss]
pos_sentences=[nltk.pos_tag(sent) for sent in tokenized_sent]
pos_sentences
# Out:
# [[('Jatin', 'NNP'),
#   ('nandal', 'NN'),
#   ('who', 'WP'),
#   ('is', 'VBZ'),
#   ('backchode', 'VBN'),
#   ('in', 'IN'),
#   ('nature', 'NN'),
#   ('is', 'VBZ'),
#   ('running', 'VBG'),
#   ('and', 'CC'),
#   ('doing', 'VBG'),
#   ('backchode', 'NN'),
#   ('.', '.')]]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, 'r')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

filename = "/content/drive/My Drive/Flickr8k.token.txt"
# load descriptions
doc = load_doc(filename)
print(doc[:300])
# Out:
# 1000268201_693b08cb0e.jpg#0	A child in a pink dress is climbing up a set of stairs in an entry way .
# 1000268201_693b08cb0e.jpg#1	A girl going into a wooden building .
# 1000268201_693b08cb0e.jpg#2	A little girl climbing into a wooden playhouse .
# 1000268201_693b08cb0e.jpg#3	A little girl climbing the s

# %%
def load_descriptions(doc):
	mapping = dict()
	# process lines
	for line in doc.split('\n'):
		# split line by white space
		tokens = line.split()
		if len(line) < 2:
			continue
		# take the first token as the image id, the rest as the description
		image_id, image_desc = tokens[0], tokens[1:]
		# extract filename from image id
		image_id = image_id.split('.')[0]
		# convert description tokens back to string
		image_desc = ' '.join(image_desc)
		# create the list if needed
		if image_id not in mapping:
			mapping[image_id] = list()
		# store description
		mapping[image_id].append(image_desc)
	return mapping

# parse descriptions
descriptions = load_descriptions(doc)
print('Loaded: %d ' % len(descriptions))
# Out:
# Loaded: 8092

# %%
list(descriptions.keys())[:5]
# Out:
# ['1000268201_693b08cb0e',
#  '1001773457_577c3a7d70',
#  '1002674143_1b742ab4b8',
#  '1003163366_44323f5815',
#  '1007129816_e794419615']

# %%
len(descriptions.keys())
# Out:
# 8092

# %%
for key,value in descriptions.items():
  print(key)
# Out:
# 1000268201_693b08cb0e
# 1001773457_577c3a7d70
# 1002674143_1b742ab4b8
# 1003163366_44323f5815
# 1007129816_e794419615
# 1007320043_627395c3d8
# 1009434119_febe49276a
# 1012212859_01547e3f17
# 1015118661_980735411b
# 1015584366_dfcec3c85a
# 101654506_8eb26cfb60
# 101669240_b2d3e7f17b
# 1016887272_03199f49c4
# 1019077836_6fc9b15408
# 1019604187_d087bf9a5f
# 1020651753_06077ec457
# 1022454332_6af2c1449a
# 1022454428_b6b660a67b
# 1022975728_75515238d8
# 102351840_323e3de834
# 1024138940_f1fefbdce1
# 102455176_5f8ead62d5
# 1026685415_0431cbf574
# 1028205764_7e8df9a2ea
# 1030985833_b0902ea560
# 103106960_e8a41d64f8
# 103195344_5d2dc613a3
# 103205630_682ca7285b
# 1032122270_ea6f0beedb
# 1032460886_4a598ed535
# 1034276567_49bb87c51c
# 104136873_5b5d41be75
# 1042020065_fb3d3ba5ba
# 1042590306_95dea0916c
# 1045521051_108ebc19be
# 1048710776_bb5b0a5c7c
# 1052358063_eae6744153
# 105342180_4d4a40b47f
# 1053804096_ad278b25f1
# 1055623002_8195a43714
# 1055753357_4fa3d8d693
# 1056249424_ef2a2e041c
# ...

# %%
descriptions['1000268201_693b08cb0e']
# Out:
# ['A child in a pink dress is climbing up a set of stairs in an entry way .',
#  'A girl going into a wooden building .',
#  'A little girl climbing into a wooden playhouse .',
#  'A little girl climbing the stairs to her playhouse .',
#  'A little girl in a pink dress going into a wooden cabin .']

# %%
text=descriptions['1000268201_693b08cb0e'][0]
ss=nt.sent_tokenize(text)
tokenized_sent=[nt.word_tokenize(sent) for sent in ss]
pos_sentences=[nltk.pos_tag(sent) for sent in tokenized_sent]
pos_sentences
# Out:
# [[('A', 'DT'),
#   ('child', 'NN'),
#   ('in', 'IN'),
#   ('a', 'DT'),
#   ('pink', 'NN'),
#   ('dress', 'NN'),
#   ('is', 'VBZ'),
#   ('climbing', 'VBG'),
#   ('up', 'RP'),
#   ('a', 'DT'),
#   ('set', 'NN'),
#   ('of', 'IN'),
#   ('stairs', 'NNS'),
#   ('in', 'IN'),
#   ('an', 'DT'),
#   ('entry', 'NN'),
#   ('way', 'NN'),
#   ('.', '.')]]

# %%
verbList = list()
for key , value in descriptions.items():
  currentkey = key
  for i in range(len(descriptions[currentkey])):
    text = descriptions[currentkey][i]
    ss=nt.sent_tokenize(text)
    tokenized_sent=[nt.word_tokenize(sent) for sent in ss]
    pos_sentences=[nltk.pos_tag(sent) for sent in tokenized_sent]
    pos_sentences
  for j in range(len(pos_sentences[0])):
    if(pos_sentences[0][j][1]=='VBG' or pos_sentences[0][j][1]=='VB' or pos_sentences[0][j][1]=='VBD' or pos_sentences[0][j][1]=='VBN' or pos_sentences[0][j][1]=='VBP' or pos_sentences[0][j][1]=='VBZ'):
      verbList.append(pos_sentences[0][j][0])

# %%
print(len(verbList))
# Out:
# 1248

# %%
len(verbList)
# Out:
# 12626

# %%
def Remove(duplicate): 
    final_list = [] 
    for num in duplicate: 
        if num not in final_list: 
            final_list.append(num) 
    return final_list
  
verbList = Remove(verbList)

# %%
verbList
print(len(verbList))
# Out:
# 1246

# %%
for i in range(len(verbList)):
  if verbList[i]=='is' or verbList[i]=='are':
    verbList.remove(verbList[i])

# %%
len(verbList)
# Out:
# 1246

# %%
# with open('/home/rajat/Desktop/verbs.txt', 'w') as f:
#     for item in verList:
#         f.write("%s\n" % item)
        
import sys
sys.stdout = open('verbs.txt', 'w') 
for item in verbList:
  print(item)

# %%
from google.colab import files
files.download('verbs.txt')

# %%
# Out:
# 'verbs.txt'

# %%
sys.stdin = open('verbs.txt', 'r')

# %%
pos_sentences[0][0][1]
# Out:
# 'DT'

# %%
len(pos_sentences[0])
# Out:
# 18

# %%
tempList = list()
for i in range(len(pos_sentences[0])):
  if(pos_sentences[0][i][1]=='VBG' or pos_sentences[0][i][1]=='VB' or pos_sentences[0][i][1]=='VBD' or pos_sentences[0][i][1]=='VBN' or pos_sentences[0][i][1]=='VBP' or pos_sentences[0][i][1]=='VBZ'):
    tempList.append(pos_sentences[0][i][0])

# %%
tempList
# Out:
# ['is', 'climbing']
